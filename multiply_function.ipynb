# %% [markdown]
# <a href="https://colab.research.google.com/github/McDonaldIbekwe/Google-Colab-to-GitHub/blob/main/multiply_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiply(num1, num2):
    return num1 * num2


number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))
result = multiply(number1, number2)
print(f"{number1} x {number2} = {result}")
