# %% [markdown]
# <a href="https://colab.research.google.com/github/McDonaldIbekwe/Google-Colab-to-GitHub/blob/main/division_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def division(num1, num2):
    return num1 / num2


number1 = input("Enter the first number: ")
number2 = input("Enter the second number: ")
print(f'{number1} / {number2} = {division(float(number1), float(number2)):,.2f}')
